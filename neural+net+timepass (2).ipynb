# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import sklearn.datasets
import sklearn.linear_model
import matplotlib
from scipy.special import expit

# %%
np.random.seed(0)
X, Y = sklearn.datasets.make_circles(200, noise = 0.04)
plt.scatter(X[:,0], X[:,1], s = 40, c = Y, cmap = plt.cm.Spectral)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def plot_decision_boundary(function):
    x_min, x_max = X[:,0].min() - 0.5, X[:,0].max() + 0.5
    y_min, y_max = X[:,1].min() - 0.5, X[:,1].max() + 0.5
    h = 0.01
    
    x, y = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = function(np.c_[x.ravel(), y.ravel()])
    Z = Z.reshape(x.shape)
    
    plt.contourf(x, y, Z, cmap = plt.cm.Spectral)
    plt.scatter(X[:,0], X[:,1], c = Y, cmap = plt.cm.Spectral)

# %%
#Initialize hyper-parameters
num_examples = len(X)
input_layers = 2
output_layers = 2

learning_rate = 0.001
regularizer = 0.01

# %%
#Cross-entropic loss
def loss(model) :
    w1, b1, w2, b2 = model['w1'], model['b1'], model['w2'], model['b2'] 
    
    z1 = X.dot(w1) + b1
    a1 = expit(z1)
    z2 = a1.dot(w2) + b2
    exp_scores = np.exp(z2)
    normalized_scores = exp_scores/np.sum(exp_scores, axis = 1, keepdims = True)
    
    log_scores = -1 * np.log(normalized_scores[range(num_examples), Y])
    data_loss = np.sum(log_scores)
    data_loss += (regularizer/2) * ( np.sum(np.square(w1)) + np.sum(np.square(w2)) )
    
    return data_loss/num_examples

# %%
def hypothesis(model, x) :
    w1, b1, w2, b2 = model['w1'], model['b1'], model['w2'], model['b2']
    
    z1 = x.dot(w1) + b1
    a1 = expit(z1)
    z2 = a1.dot(w2) + b2
    
    #Softmax normalization of scores
    exp_scores = np.exp(z2)
    probs = exp_scores/np.sum(exp_scores, axis = 1, keepdims = True)

    return np.argmax(probs, axis = 1)

# %%
#Gradient descent using backpropagation
def train_model(hidden_layers, epochs = 60000, print_loss = False) :
    np.random.seed(0)
    w1 = np.random.randn(input_layers, hidden_layers)/ np.sqrt(input_layers)
    b1 = np.zeros((1, hidden_layers))
    w2 = np.random.randn(hidden_layers, output_layers)/ np.sqrt(hidden_layers)
    b2 = np.zeros((1, output_layers))
    
    model = {}
    
    for i in range(epochs) :

        #Forward propagation
        z1 = X.dot(w1) + b1
        a1 = expit(z1)
        z2 = a1.dot(w2) + b2
        
        exp_scores = np.exp(z2)
        probs = exp_scores/np.sum(exp_scores, axis = 1, keepdims = True)
        
        #Backpropagation
        delta3 = probs
        delta3[range(num_examples), Y] -= 1
        dw2 = (a1.T).dot(delta3)
        db2 = np.sum(delta3, axis = 0, keepdims = True)
        
        delta2 = np.multiply(delta3.dot(w2.T), a1 * (1 - a1))
        dw1 = np.dot(X.T, delta2)
        db1 = np.sum(delta2, axis = 0)
        
        dw2 += regularizer * w2
        dw1 += regularizer * w1
        
        w1 += -1 * learning_rate * dw1
        w2 += -1 * learning_rate * dw2
        b1 += -1 * learning_rate * db1
        b2 += -1 * learning_rate * db2
        
        model = {'w1' : w1, 'w2' : w2, 'b1' : b1, 'b2' : b2}
        
        if print_loss and i % 1000 == 0 :
            print("Loss after epoch ", i, " is ", loss(model))
            
    return model

# %%
model = train_model(3, print_loss = True)
plot_decision_boundary(lambda x : hypothesis(model, x))
plt.title("Decision boundary with 3 hidden sigmoid neurons")
# Out:
# Loss after epoch  0  is  0.700155466356
# Loss after epoch  1000  is  0.690132461629
# Loss after epoch  2000  is  0.675814349292
# Loss after epoch  3000  is  0.649684212883
# Loss after epoch  4000  is  0.558615296267
# Loss after epoch  5000  is  0.474348069449
# Loss after epoch  6000  is  0.423239497816
# Loss after epoch  7000  is  0.387477532262
# Loss after epoch  8000  is  0.35980591962
# Loss after epoch  9000  is  0.337278467863
# Loss after epoch  10000  is  0.318473137134
# Loss after epoch  11000  is  0.302564112213
# Loss after epoch  12000  is  0.288972064572
# Loss after epoch  13000  is  0.27725463448
# Loss after epoch  14000  is  0.267070022573
# Loss after epoch  15000  is  0.258152995586
# Loss after epoch  16000  is  0.2502955183
# Loss after epoch  17000  is  0.243332283581
# Loss after epoch  18000  is  0.237130264323
# Loss after epoch  19000  is  0.2315811433
# Loss after epoch  20000  is  0.226595760321
# Loss after epoch  21000  is  0.222099991935
# Loss after epoch  22000  is  0.218031665553
# Loss after epoch  23000  is  0.214338227857
# Loss after epoch  24000  is  0.210974962781
# Loss after epoch  25000  is  0.20790360701
# Loss after epoch  26000  is  0.205091252137
# Loss after epoch  27000  is  0.202509455578
# Loss after epoch  28000  is  0.200133507118
# Loss after epoch  29000  is  0.197941814683
# Loss after epoch  30000  is  0.195915383073
# Loss after epoch  31000  is  0.194037364916
# Loss after epoch  32000  is  0.192292665722
# Loss after epoch  33000  is  0.190667586017
# Loss after epoch  34000  is  0.189149484213
# Loss after epoch  35000  is  0.187726446138
# Loss after epoch  36000  is  0.186386954807
# Loss after epoch  37000  is  0.185119575479
# Loss after epoch  38000  is  0.183912720904
# Loss after epoch  39000  is  0.182754655264
# Loss after epoch  40000  is  0.181634015986
# Loss after epoch  41000  is  0.180541155602
# Loss after epoch  42000  is  0.179470271973
# Loss after epoch  43000  is  0.178421541191
# Loss after epoch  44000  is  0.177401986678
# Loss after epoch  45000  is  0.176424370362
# Loss after epoch  46000  is  0.175504198193
# Loss after epoch  47000  is  0.174655296398
# Loss after epoch  48000  is  0.173885483328
# Loss after epoch  49000  is  0.173194798146
# Loss after epoch  50000  is  0.172577095646
# Loss after epoch  51000  is  0.172023244037
# Loss after epoch  52000  is  0.171523811397
# Loss after epoch  53000  is  0.171070466083
# Loss after epoch  54000  is  0.170656366001
# Loss after epoch  55000  is  0.170276043799
# Loss after epoch  56000  is  0.169925136702
# Loss after epoch  57000  is  0.169600122055
# Loss after epoch  58000  is  0.169298107975
# Loss after epoch  59000  is  0.169016680792
